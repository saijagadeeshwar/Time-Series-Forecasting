# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
def load_and_preprocess_data(filename):
    data = pd.read_csv(filename, index_col=0).transpose()
    data.index = pd.to_datetime(data.index)
    close_prices = data['4. close'].values.reshape(-1, 1)
    scaler = MinMaxScaler(feature_range=(0, 1))
    close_prices = scaler.fit_transform(close_prices)
    return close_prices, scaler

# %%
data, scaler = load_and_preprocess_data('AAPL_stock_data_alpha.csv')

# %%
def create_dataset(data, look_back=60):
    X, Y = [], []
    for i in range(len(data) - look_back - 1):
        a = data[i:(i + look_back), 0]
        X.append(a)
        Y.append(data[i + look_back, 0])
    return np.array(X), np.array(Y)

X, Y = create_dataset(data)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv1D, Flatten, MaxPooling1D, BatchNormalization, Activation

def create_alexnet_model(input_shape):
    model = Sequential()
    model.add(Conv1D(filters=96, kernel_size=11, strides=4, padding='same', activation='relu', input_shape=(input_shape, 1)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=3, strides=2))
    model.add(Conv1D(filters=256, kernel_size=5, padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=3, strides=2))
    model.add(Conv1D(filters=384, kernel_size=3, padding='same', activation='relu'))
    model.add(Conv1D(filters=384, kernel_size=3, padding='same', activation='relu'))
    model.add(Conv1D(filters=256, kernel_size=3, padding='same', activation='relu'))
    model.add(MaxPooling1D(pool_size=3, strides=2))
    model.add(Flatten())
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1))  # Output layer for regression
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_squared_error'])
    return model

# Prepare model
model = create_alexnet_model(60)  # Assuming look_back=60
# Out:
# C:\Users\jatav\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(X_train, Y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 28s 192ms/step - loss: 3.8277 - mean_squared_error: 3.8277 - val_loss: 0.0690 - val_mean_squared_error: 0.0690
# Epoch 2/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 189ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0504 - val_mean_squared_error: 0.0504
# Epoch 3/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 189ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0428 - val_mean_squared_error: 0.0428
# Epoch 4/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 188ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0276 - val_mean_squared_error: 0.0276
# Epoch 5/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 190ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0092 - val_mean_squared_error: 0.0092
# Epoch 6/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 189ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 7/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 188ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 3.7278e-04 - val_mean_squared_error: 3.7278e-04
# Epoch 8/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 189ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 8.2979e-04 - val_mean_squared_error: 8.2979e-04
# Epoch 9/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 189ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 10/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 189ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 3.9332e-04 - val_mean_squared_error: 3.9332e-04
# Epoch 11/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 188ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 2.0695e-04 - val_mean_squared_error: 2.0695e-04
# Epoch 12/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 188ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 5.1216e-04 - val_mean_squared_error: 5.1216e-04
# Epoch 13/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 27s 221ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 3.5958e-04 - val_mean_squared_error: 3.5958e-04
# Epoch 14/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 198ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 5.9446e-04 - val_mean_squared_error: 5.9446e-04
# Epoch 15/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 199ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 4.8684e-04 - val_mean_squared_error: 4.8684e-04
# Epoch 16/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 197ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 17/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 199ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 3.8942e-04 - val_mean_squared_error: 3.8942e-04
# Epoch 18/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 199ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 5.6370e-04 - val_mean_squared_error: 5.6370e-04
# Epoch 19/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 199ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 20/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 201ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 3.3226e-04 - val_mean_squared_error: 3.3226e-04
# Epoch 21/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 199ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 22/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 198ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 23/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 199ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 4.0331e-04 - val_mean_squared_error: 4.0331e-04
# Epoch 24/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 199ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 5.4462e-04 - val_mean_squared_error: 5.4462e-04
# Epoch 25/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 198ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 3.2939e-04 - val_mean_squared_error: 3.2939e-04
# Epoch 26/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 198ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 2.0810e-04 - val_mean_squared_error: 2.0810e-04
# Epoch 27/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 198ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 4.2518e-04 - val_mean_squared_error: 4.2518e-04
# Epoch 28/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 198ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 29/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 199ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 8.8829e-04 - val_mean_squared_error: 8.8829e-04
# Epoch 30/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 200ms/step - loss: 9.6229e-04 - mean_squared_error: 9.6229e-04 - val_loss: 5.3784e-04 - val_mean_squared_error: 5.3784e-04
# Epoch 31/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 199ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.9132e-04 - val_mean_squared_error: 7.9132e-04
# Epoch 32/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 198ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 33/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 203ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 3.3977e-04 - val_mean_squared_error: 3.3977e-04
# Epoch 34/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 200ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 7.9329e-04 - val_mean_squared_error: 7.9329e-04
# Epoch 35/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 200ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 36/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 199ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 5.1154e-04 - val_mean_squared_error: 5.1154e-04
# Epoch 37/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 198ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 4.2770e-04 - val_mean_squared_error: 4.2770e-04
# Epoch 38/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 198ms/step - loss: 9.3824e-04 - mean_squared_error: 9.3824e-04 - val_loss: 2.5474e-04 - val_mean_squared_error: 2.5474e-04
# Epoch 39/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 199ms/step - loss: 8.6456e-04 - mean_squared_error: 8.6456e-04 - val_loss: 1.9759e-04 - val_mean_squared_error: 1.9759e-04
# Epoch 40/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 200ms/step - loss: 9.3205e-04 - mean_squared_error: 9.3205e-04 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 41/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 199ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 42/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 202ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 4.3390e-04 - val_mean_squared_error: 4.3390e-04
# Epoch 43/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 200ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 44/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 198ms/step - loss: 9.4291e-04 - mean_squared_error: 9.4291e-04 - val_loss: 2.3761e-04 - val_mean_squared_error: 2.3761e-04
# Epoch 45/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 200ms/step - loss: 9.0850e-04 - mean_squared_error: 9.0850e-04 - val_loss: 4.0017e-04 - val_mean_squared_error: 4.0017e-04
# Epoch 46/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 26s 208ms/step - loss: 8.3219e-04 - mean_squared_error: 8.3219e-04 - val_loss: 2.7977e-04 - val_mean_squared_error: 2.7977e-04
# Epoch 47/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 26s 208ms/step - loss: 7.9587e-04 - mean_squared_error: 7.9587e-04 - val_loss: 3.3440e-04 - val_mean_squared_error: 3.3440e-04
# Epoch 48/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 206ms/step - loss: 8.1713e-04 - mean_squared_error: 8.1713e-04 - val_loss: 6.8868e-04 - val_mean_squared_error: 6.8868e-04
# Epoch 49/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 194ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 5.3845e-04 - val_mean_squared_error: 5.3845e-04
# Epoch 50/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 193ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 3.4268e-04 - val_mean_squared_error: 3.4268e-04

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# Calculate additional performance metrics
mae = mean_absolute_error(Y_test, predictions)
r2 = r2_score(Y_test, predictions)

print("Mean Absolute Error (MAE):", mae)
print("R-squared (R²):", r2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from sklearn.metrics import mean_absolute_error, r2_score
#       3 # Calculate additional performance metrics
# ----> 4 mae = mean_absolute_error(Y_test, predictions)
#       5 r2 = r2_score(Y_test, predictions)
#       7 print("Mean Absolute Error (MAE):", mae)
#
# NameError: name 'Y_test' is not defined

# %%
def plot_results(actual, predictions, start=0, end=100):
    plt.figure(figsize=(10, 6))
    plt.plot(range(start, end), actual[start:end], label='Actual Prices', color='blue')
    plt.plot(range(start, end), predictions[start:end], label='Predicted Prices', color='red')
    plt.title('Stock Price Prediction - Zoomed In View')
    plt.xlabel('Time')
    plt.ylabel('Normalized Price')
    plt.legend()
    plt.show()

# Predict and plot
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
actual = scaler.inverse_transform(Y_test.reshape(-1, 1))

# Zoom in on the first 100 data points
plot_results(actual.flatten(), predictions.flatten(), start=0, end=100)
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step

# %%
model.fit(X_train, Y_train, epochs=30, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 198ms/step - loss: 7.8875e-04 - mean_squared_error: 7.8875e-04 - val_loss: 2.1071e-04 - val_mean_squared_error: 2.1071e-04
# Epoch 2/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 197ms/step - loss: 8.8835e-04 - mean_squared_error: 8.8835e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 3/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 194ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 2.7571e-04 - val_mean_squared_error: 2.7571e-04
# Epoch 4/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 193ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.8361e-04 - val_mean_squared_error: 5.8361e-04
# Epoch 5/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 196ms/step - loss: 9.3863e-04 - mean_squared_error: 9.3863e-04 - val_loss: 3.4272e-04 - val_mean_squared_error: 3.4272e-04
# Epoch 6/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 194ms/step - loss: 7.1583e-04 - mean_squared_error: 7.1583e-04 - val_loss: 6.2786e-04 - val_mean_squared_error: 6.2786e-04
# Epoch 7/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 194ms/step - loss: 5.6733e-04 - mean_squared_error: 5.6733e-04 - val_loss: 8.7939e-04 - val_mean_squared_error: 8.7939e-04
# Epoch 8/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 193ms/step - loss: 7.3659e-04 - mean_squared_error: 7.3659e-04 - val_loss: 4.7971e-04 - val_mean_squared_error: 4.7971e-04
# Epoch 9/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 190ms/step - loss: 8.4058e-04 - mean_squared_error: 8.4058e-04 - val_loss: 3.3888e-04 - val_mean_squared_error: 3.3888e-04
# Epoch 10/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 187ms/step - loss: 5.8775e-04 - mean_squared_error: 5.8775e-04 - val_loss: 4.5965e-04 - val_mean_squared_error: 4.5965e-04
# Epoch 11/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 187ms/step - loss: 7.4257e-04 - mean_squared_error: 7.4257e-04 - val_loss: 3.6030e-04 - val_mean_squared_error: 3.6030e-04
# Epoch 12/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 187ms/step - loss: 6.7960e-04 - mean_squared_error: 6.7960e-04 - val_loss: 2.4245e-04 - val_mean_squared_error: 2.4245e-04
# Epoch 13/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 187ms/step - loss: 6.3704e-04 - mean_squared_error: 6.3704e-04 - val_loss: 9.9296e-04 - val_mean_squared_error: 9.9296e-04
# Epoch 14/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 189ms/step - loss: 7.9404e-04 - mean_squared_error: 7.9404e-04 - val_loss: 2.3874e-04 - val_mean_squared_error: 2.3874e-04
# Epoch 15/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 193ms/step - loss: 6.6611e-04 - mean_squared_error: 6.6611e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 16/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 189ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 3.5847e-04 - val_mean_squared_error: 3.5847e-04
# Epoch 17/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 189ms/step - loss: 8.7451e-04 - mean_squared_error: 8.7451e-04 - val_loss: 3.3460e-04 - val_mean_squared_error: 3.3460e-04
# Epoch 18/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 191ms/step - loss: 6.8666e-04 - mean_squared_error: 6.8666e-04 - val_loss: 7.7584e-04 - val_mean_squared_error: 7.7584e-04
# Epoch 19/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 189ms/step - loss: 9.4413e-04 - mean_squared_error: 9.4413e-04 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 20/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 189ms/step - loss: 8.9962e-04 - mean_squared_error: 8.9962e-04 - val_loss: 2.0033e-04 - val_mean_squared_error: 2.0033e-04
# Epoch 21/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 194ms/step - loss: 7.1173e-04 - mean_squared_error: 7.1173e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 22/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 25s 204ms/step - loss: 6.3229e-04 - mean_squared_error: 6.3229e-04 - val_loss: 2.4365e-04 - val_mean_squared_error: 2.4365e-04
# Epoch 23/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 189ms/step - loss: 6.5154e-04 - mean_squared_error: 6.5154e-04 - val_loss: 3.1546e-04 - val_mean_squared_error: 3.1546e-04
# Epoch 24/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 190ms/step - loss: 5.2419e-04 - mean_squared_error: 5.2419e-04 - val_loss: 3.2067e-04 - val_mean_squared_error: 3.2067e-04
# Epoch 25/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 189ms/step - loss: 8.4547e-04 - mean_squared_error: 8.4547e-04 - val_loss: 2.6781e-04 - val_mean_squared_error: 2.6781e-04
# Epoch 26/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 189ms/step - loss: 6.9971e-04 - mean_squared_error: 6.9971e-04 - val_loss: 3.3451e-04 - val_mean_squared_error: 3.3451e-04
# Epoch 27/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 195ms/step - loss: 6.4112e-04 - mean_squared_error: 6.4112e-04 - val_loss: 2.4052e-04 - val_mean_squared_error: 2.4052e-04
# Epoch 28/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 196ms/step - loss: 6.6391e-04 - mean_squared_error: 6.6391e-04 - val_loss: 2.9085e-04 - val_mean_squared_error: 2.9085e-04
# Epoch 29/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 24s 191ms/step - loss: 7.2425e-04 - mean_squared_error: 7.2425e-04 - val_loss: 4.3720e-04 - val_mean_squared_error: 4.3720e-04
# Epoch 30/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 189ms/step - loss: 5.3735e-04 - mean_squared_error: 5.3735e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010

# %%
def plot_results(actual, predictions, start=0, end=100):
    plt.figure(figsize=(10, 6))
    plt.plot(range(start, end), actual[start:end], label='Actual Prices', color='blue')
    plt.plot(range(start, end), predictions[start:end], label='Predicted Prices', color='red')
    plt.title('Stock Price Prediction - Zoomed In View')
    plt.xlabel('Time')
    plt.ylabel('Normalized Price')
    plt.legend()
    plt.show()

# Predict and plot
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
actual = scaler.inverse_transform(Y_test.reshape(-1, 1))

# Zoom in on the first 100 data points
plot_results(actual.flatten(), predictions.flatten(), start=0, end=100)
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
